# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv',sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
display(hh_data.head(3))
display(hh_data.tail(3))
display(hh_data.shape[0])
display(hh_data.shape[1])
# Out:
#                                    Пол, возраст          ЗП
# 0    Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.  \
# 1     Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982  20000 руб.
#
#   Ищет работу на должность:
# 0   Системный администратор  \
# 1      Технический писатель
# 2                  Оператор
#
#                         Город, переезд, командировки
# 0  Советск (Калининградская область) , не готов к...  \
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
#
#                                            Занятость
# 0  частичная занятость, проектная работа, полная ...  \
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
#
#                                               График
# 0  гибкий график, полный день, сменный график, ва...  \
# 1  гибкий график, полный день, сменный график, уд...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
display(hh_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
display(hh_data.describe())
# Out:
#                                          Пол, возраст          ЗП
# count                                           44744       44744  \
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:
# count                      44744  \
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость
# count                                               44744             44744  \
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
# Вводится функция определяющая уровень образования
# words - это список слов разделенных проблеом (в данном случае) из столбца <Образование и ВУЗ>
def education(words: list[str]):
    if words[0] == 'Неоконченное':
        return 'неоконченное высшее'
    elif words[0] == 'Высшее':
        return 'высшее'
    elif words[1] == 'специальное':
        return 'среднее специальное'
    else: 
        return 'среднее'

hh_data['Образование'] = hh_data['Образование и ВУЗ'].astype(str).apply(lambda x : education(x.split()))
hh_data = hh_data.drop(['Образование и ВУЗ'],axis=1)
display(hh_data['Образование'].unique())
mask = hh_data['Образование'] == 'среднее'
print(hh_data[mask]['Образование'].count())
# Out:
# array(['неоконченное высшее', 'высшее', 'среднее специальное', 'среднее'],
#       dtype=object)
# 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# На примере строки <Женщина , 21 год , родилась 13 января 2000>
# Сначала строку, состоящую из Заглавных букв делим по <",">, первый элемент ЖЕНЩИНА, первая буква Ж это Пол
# Второй элемент <21 год>  делим уже по " " и первый элемент второго разделения 21 это Возраст

# Первая буква первого элемента после разделения по "," это Пол 
def  gender(word):
    word = word.upper().strip()
    return word[0]

# Второй элемент разделения по  <","> тоже делим, но уже на пробелы,  первый элемент такого разделения это Возраст
def age(word):
    word = word.strip()
    word = word.split()
    return word[0]

hh_data['Пол'] = hh_data['Пол, возраст'].astype(str). \
    apply( lambda x : gender(x.split(',')[0]) )    # Разделение каждой строки столбца на элементы списка первая буква первого эелемента это Пол

hh_data['Возраст'] = hh_data['Пол, возраст'].astype(str). \
    apply( lambda x : age(x.split(',')[1]) ).astype('Int64') # Второй элемент разделения по  <",">

hh_data = hh_data.drop(['Пол, возраст'],axis=1)

gender_percent = hh_data['Пол'].value_counts(normalize=True)*100
print(f'{gender_percent}')
hh_data['Возраст'].mean()
# Out:
# Пол
# М    80.929287
# Ж    19.070713
# Name: proportion, dtype: float64
# 32.19674146254246

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
# Функция принимает строку с опытом работы
# Выделяет в переменную exp_words список слов, первые два слова в списке [0](Опыт) и [1](работы)
# Затем идет срок работы
# Определяется как написан срок работы и возвращается кол-во месяцев работы

def get_experience(arg):
    
    if (pd.isna(arg)) or (arg == 'Не указано'):
        return np.nan

    exp_words = arg.split()[2:] # Сразу отсекаем элементы [0](Опыт) и [1](работы)

    len_exp_words = len(exp_words) # Определяем список, для опыта работы требуется не более 4 элементов например: 9 лет 9 месяцев   
    if len_exp_words > 3:
        exp_words = exp_words[:4]
               
    if ('год' in exp_words[1]) or (exp_words[1] == 'лет'): # Возможные опыты работы: 1 год, 3 года, 5 лет

        if len_exp_words > 3: # Проверка есть в списке индекс слова, которое может указывать на месяцы после указания лет
            if 'месяц' in exp_words[3]:
                return int(exp_words[0])*12+int(exp_words[2])
        return int(exp_words[0])*12 # Число слов меньше трех и второе слово год/лет, значит возвращаем просто кол-во лет x 12

    elif 'месяц' in exp_words[1]: # Если в первом слове только месяц, то возвращаем просто кол-во месяцев
        return int(exp_words[0])

    

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(lambda x : get_experience(x))
hh_data = hh_data.drop(['Опыт работы'],axis=1)

print(hh_data['Опыт работы (месяц)'].median())
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск',
                  'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']

# Так как в дальнейшем проверка осуществляется только по верхнему регистру
# переводим список городов в верхний регистр
million_cities = list(map(lambda x: x.upper(), million_cities))

# Определение типа города
# Аргумент передаётся в верхнем регистре (ЗАГЛАВНЫМИ буквами)
def city(arg):
    arg = arg.strip() # Убираем возможные пробелы справа и слева
    if 'МОСКВА' in arg:
        return 'Москва'
    elif 'ПЕТЕРБУРГ' in arg:
        return 'Санкт-Петербург'
    elif arg in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'

# Одинаковая функция для признаков переезда и командировки
# Аргумент передаётся в верхнем регистре (ЗАГЛАВНЫМИ буквами)
# Если первое слово НЕ, значит не готов, не хочет, не желает и пр.
trip_move_ready = lambda arg: arg.strip().split()[0] != 'НЕ'

# Решил сделать так: в цикле пройтись по всем строкам в столбце ['Город, переезд, командировки']
# И добавлять в соответсвующие признакам списки значения
# Затем эти списки конвертировать в соответсвующие признакам столбцы
list_city = []
list_move = []
list_trip = []

for words in hh_data['Город, переезд, командировки']:
    words = words.upper()
    list_words = words.split(',')
    list_city.append(city(list_words[0]))
    if 'КОМАНДИРОВК' not in words:
        list_trip.append(1==2) # Так решил добавлять False в случае отсутствия информации о командировках
    if 'ПЕРЕЕ' not in words:
        list_move.append(1==2) # Так решил добавлять False в случае отсутствия информации о переезде
    
    for word in list_words[1:]:
        if 'ПЕРЕЕ' in word: # Переезд, переехать и прочее
            list_move.append(trip_move_ready(word))            
        elif 'КОМАНДИРОВК' in word:
            list_trip.append(trip_move_ready(word))
            

hh_data['Город'] = pd.DataFrame(list_city)
hh_data['Готовность к переезду'] = pd.DataFrame(list_move)
hh_data['Готовность к командировкам'] = pd.DataFrame(list_trip)
hh_data = hh_data.drop(['Город, переезд, командировки'],axis=1)

display(hh_data['Город'].value_counts(normalize=True))

mask = hh_data['Готовность к переезду'] & hh_data['Готовность к командировкам']

display(hh_data[mask]['Готовность к переезду'].sum() / hh_data.shape[0])
# Out:
# Город
# Москва              0.371469
# другие              0.354327
# город-миллионник    0.163866
# Санкт-Петербург     0.110339
# Name: proportion, dtype: float64
# 0.3186572501340962

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Создание и удаление временных признаков
hh_data['полная занятость'] = hh_data['Занятость'].apply(lambda x : 'полная занятость' in x)
hh_data['частичная занятость'] = hh_data['Занятость'].apply(lambda x : 'частичная занятость' in x)
hh_data['проектная работа'] = hh_data['Занятость'].apply(lambda x : 'проектная работа' in x)
hh_data['волонтерство'] = hh_data['Занятость'].apply(lambda x : 'волонтерство' in x)
hh_data['стажировка'] = hh_data['Занятость'].apply(lambda x : 'стажировка' in x)

mask =  hh_data['проектная работа'] & hh_data['волонтерство']

display(sum(hh_data[mask]['проектная работа']))

hh_data['полный день'] = hh_data['График'].apply(lambda x : 'полный день' in x)
hh_data['сменный график'] = hh_data['График'].apply(lambda x : 'сменный график' in x)
hh_data['гибкий график'] = hh_data['График'].apply(lambda x : 'гибкий график' in x)
hh_data['удаленная работа'] = hh_data['График'].apply(lambda x : 'удаленная работа' in x)
hh_data['вахтовый метод'] = hh_data['График'].apply(lambda x : 'вахтовый метод' in x)

mask = hh_data['вахтовый метод'] & hh_data['гибкий график']

display(sum(hh_data[mask]['вахтовый метод']))

hh_data = hh_data.drop(columns=['Занятость','График'],axis=1)

# При необходимости проверки снять комментарий ниже
#hh_data.head(1)
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# Создание dataframe из файла с валютами и их признаками
currencies = pd.read_csv('data/ExchangeRates/ExchangeRates.csv',sep=',')

# %%
# Конвертация в формат datetime признака date в таблице валют 
currencies['date'] = pd.to_datetime(
    currencies['date'].apply(
        lambda x : x.split('/')[0] +'/' + x.split('/')[1] +'/20' + x.split('/')[2]
        )
    ,format='%d/%m/%Y'
    )

# При необходимости проверки снять комментарий ниже
#currencies.info()

# %%
# Приведение к типу datetime признака 'Обновление резюме'
# Создание нового признака с отдельно выделенной датой

hh_data['Дата обновления резюме'] = \
    pd.to_datetime(
                hh_data['Обновление резюме'],format='%d.%m.%Y %H:%M'
                ).dt.date.astype('datetime64[ns]')

# %%
# Вводим словарь перевода названия валют в ISO наименование
# Для избежания возможных неточностей все ключи словаря заданы с ЗАГЛАВНОЙ буквы
cur_dict = {'ГРН' : 'UAH', 'USD' : 'USD', 'РУБ' : 'RUB', 
            'EUR' : 'EUR', 'БЕЛРУБ' : 'BYN', 'KGS' : 'KGS',
            'СУМ' : 'UZS', 'AZN' : 'AZN', 'KZT' : 'KZT'}

# %%
# Создаются временные столбцы с суммой зарплаты и наменованием валюты

hh_data['Сумма ЗП в валюте'] = hh_data['ЗП'].astype(str).apply(
    lambda x : x.split()[0].strip()
    ).astype(float)

hh_data['Код валюты'] = hh_data['ЗП'].astype(str).apply(
    lambda x : x.upper().split()[-1].strip()
    )

hh_data['Код валюты'] = hh_data['Код валюты'].apply(lambda x : x.replace('.','')) # Убираем в наименованиях валюты точки
hh_data['Код валюты'] = hh_data['Код валюты'].apply(lambda x : cur_dict[x]) # Перевод валюты в ISO наименование

# %%
# Добавление через объединение по валюте и дате расчета её курса признаков валюты

hh_data = hh_data.merge(    
    currencies,
    how='left',
    left_on=['Дата обновления резюме','Код валюты'],
    right_on=['date','currency']
    )

# Так как в таблице с валютами нет рублей, то для рублей признаки курса и пропорции задаются "вручную"
mask = hh_data['Код валюты']=='RUB'
hh_data.loc[mask,'close'] = 1
hh_data.loc[mask,'proportion'] = 1

# При необходимости проверки снять комментарий ниже
# display(hh_data.head(3))

# %%
# Создание нового столбца и удаление всех промежуточных столбцов
hh_data['ЗП (руб)'] = hh_data['Сумма ЗП в валюте'] * hh_data['close'] / hh_data['proportion']

hh_data = hh_data.drop(columns=['ЗП','Дата обновления резюме','Сумма ЗП в валюте','Код валюты',
                                'currency','per','date','time','close','vol','proportion'],axis=1)

display(hh_data['ЗП (руб)'].median())

# При необходимости проверки пустых значений в признаке 'ЗП (руб)' снять комментарии ниже
#mask = hh_data['ЗП (руб)'] != hh_data['ЗП (руб)']
#display(hh_data[mask])

# При необходимости просмотра данных таблицы снять комментарии ниже
#display(hh_data.info())
# Out:
# 59019.0

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = plt.figure(figsize=(12,8))
axes = fig.subplots(1, 2)
hist_bins = 20

hist_data = hh_data.copy() # Для графика отдельная копия базы

axes[0].hist(
            x=hist_data['Возраст'],
            color='Green',
            ec='Black',
            bins=hist_bins,
            label='Число соискателй',            
            lw=5
            )
axes[0].set_title('Гистограмма распределения \n возраста соискателей')
axes[0].xaxis.set_tick_params(rotation=30)
axes[0].legend()
axes[0].set_ylabel("Все соискателей")
axes[0].set_xlabel("Возраст соискателей")

#Определение порядка отображения данных на оси X
x_round = 10
min_x = 0
x = hist_data['Возраст'].max() + x_round
max_x = x_round * round( x / x_round) 
hist_step = (max_x + min_x) / hist_bins
hist_step = x_round * round( hist_step / x_round)
axes[0].set_xticks( np.arange(min_x, max_x, hist_step) )


boxplot_data = hh_data.copy() # Для графика отдельная копия базы

boxplot = sns.boxplot(
                    data=boxplot_data, 
                    x='Возраст',
                    color='Green',
                    ax=axes[1]
                    )
boxplot.set_title('Boxplot для возраста \n соискателей сайта HeadHunter')
boxplot.set_xlabel('Возраст соискателей')
axes[1].xaxis.set_tick_params(rotation=30)
axes[1].set_xticks( np.arange(min_x, max_x, hist_step) );

# Для просмотра данных, вызывающих вопросы можно снять знаки комментариев ниже 
#mask = hh_data['Возраст'] > 70
#display(hh_data[mask])
#display(hh_data['Возраст'].mode())

# %% [markdown]
# Возраст соискателей от 14 до 100 лет. Соискатели в 14 лет имеют право быть, сейчас паспорт получают уже в 14 лет. Признак "Возраст" соискателя с возрастом в 100 лет нельзя включать в данные для модели, так как вряд ли Frontend-разработчику со стажем 30 месяцев будет 100 лет.
# Как видно из графика наиболее часто ищут работу на HH 30-летние. У основного количества соискателей возраст от 20 до 50 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = plt.figure(figsize=(12,8))
axes = fig.subplots(1, 2)
hist_bins = 20

hist_data = hh_data.copy() # Для графика отдельная копия базы

axes[0].hist(
            x=hist_data['Опыт работы (месяц)'],
            color='Orange',
            ec='Black',
            bins=hist_bins,
            label='Число соискателй',            
            lw=5
            )
axes[0].set_title('Гистограмма распределения \n опыта работы соискателей')
axes[0].xaxis.set_tick_params(rotation=30)
axes[0].legend()
axes[0].set_ylabel("Все соискателей")
axes[0].set_xlabel("Опыт работы, месяц")

#Определение порядка отображения данных на оси X
x_round = 120
min_x = 0
x = hist_data['Опыт работы (месяц)'].max() + x_round
max_x = x_round * round( x / x_round) 
hist_step = (max_x + min_x) / hist_bins
hist_step = x_round * round( hist_step / x_round)
axes[0].set_xticks( np.arange(min_x, max_x, hist_step) )


boxplot_data = hh_data.copy() # Для графика отдельная копия базы

boxplot = sns.boxplot(
                    data=boxplot_data, 
                    x='Опыт работы (месяц)',
                    color='Orange',
                    ax=axes[1]
                    )
boxplot.set_title('Boxplot для опыта работы \n соискателей сайта HeadHunter')
boxplot.set_xlabel('Опыт работы, месяц')
axes[1].xaxis.set_tick_params(rotation=30)
axes[1].set_xticks( np.arange(min_x, max_x, hist_step) );

# Для просмотра данных, вызывающих вопросы можно снять знаки комментариев ниже 
#mask = hh_data['Опыт работы (месяц)'] > 600
#display(hh_data[mask])
#display(hh_data['Опыт работы (месяц)'].mode())

# %% [markdown]
# Из графиков видно, что в основном ищут работу люди с опытом работы до 240 месяцев (до 20-летнего опыта работы). Наиболее часто ищут работу соискатели с опытом работы около 80 месяцев (примерно 7 лет). Не обошлось без ошибочных данных: соискатель на вакансию "Системный администратор Windows", у которого возраст 48 лет имеет опыт работы 1188 месяцев (без года 100 лет), в модели не предусмотрен признак 'Реинкарнация', поэтому "Опыт работы" данного соискателя учитывать нельзя.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig = plt.figure(figsize=(12,16))
axes = fig.subplots(2, 2)
hist_bins = 20

hist_data = hh_data.copy() # Для графика отдельная копия базы

axes[0][0].hist(
            x=hist_data['ЗП (руб)'],
            color='Brown',
            ec='Black',
            bins=hist_bins,
            label='Число соискателй',            
            lw=5
            )
axes[0][0].set_title('Гистограмма распределения \n зарплаты соискателей')
axes[0][0].xaxis.set_tick_params(rotation=30)
axes[0][0].legend()
axes[0][0].set_ylabel("Все соискателей")
axes[0][0].set_xlabel("Заработная плата, руб")

#Определение порядка отображения данных на оси X
x_round = 2_000_000
min_x = 0
x = hist_data['ЗП (руб)'].max() + x_round
max_x = x_round * round( x / x_round) 
hist_step = (max_x + min_x) / hist_bins
hist_step = x_round * round( hist_step / x_round)
axes[0][0].set_xticks( np.arange(min_x, max_x, hist_step) )


boxplot_data = hh_data.copy() # Для графика отдельная копия базы

boxplot = sns.boxplot(
                    data=boxplot_data, 
                    x=boxplot_data['ЗП (руб)'],
                    color='Brown',
                    ax=axes[0][1]
                    )
boxplot.set_title('Boxplot для зарплаты \n соискателей сайта HeadHunter')
boxplot.set_xlabel('Заработная плата, руб')
axes[0][1].xaxis.set_tick_params(rotation=30)
axes[0][1].set_xticks( np.arange(min_x, max_x, hist_step) );

# Решил добавить более информативные графики ниже
mask = hist_data['ЗП (руб)'] <= 500_000

axes[1][0].hist(
            x=hist_data[mask]['ЗП (руб)'],
            color='Brown',
            ec='Black',
            bins=hist_bins,
            label='Число соискателй',            
            lw=5
            )
axes[1][0].set_title('Гистограмма распределения \n зарплаты соискателей до 500 000 руб')
axes[1][0].xaxis.set_tick_params(rotation=30)
axes[1][0].legend()
axes[1][0].set_ylabel("Все соискателей")
axes[1][0].set_xlabel("Заработная плата, руб")

#Определение порядка отображения данных на оси X
x_round = 50_000
min_x = 0
x = hist_data[mask]['ЗП (руб)'].max() + x_round
max_x = x_round * round( x / x_round) 
hist_step = (max_x + min_x) / hist_bins
hist_step = x_round * round( hist_step / x_round)
axes[1][0].set_xticks( np.arange(min_x, max_x, hist_step) )


boxplot = sns.boxplot(
                    data=boxplot_data, 
                    x=boxplot_data[mask]['ЗП (руб)'],
                    color='Brown',
                    ax=axes[1][1]
                    )
boxplot.set_title('Boxplot для зарплаты до 500 000 руб \n соискателей сайта HeadHunter')
boxplot.set_xlabel('Заработная плата, руб')
axes[1][1].xaxis.set_tick_params(rotation=30)
axes[1][1].set_xticks( np.arange(min_x, max_x, hist_step) );

# Для просмотра данных, вызывающих вопросы можно снять знаки комментариев ниже 
#mask = hh_data['ЗП (руб)'] > 1_000_000
#display(hh_data[mask])
#display(hh_data['ЗП (руб)'].mode())

# %% [markdown]
# В данном случае ошибочные сведения оказались критичными для построения графиков для анализа данных. Так ошибка при указании валюты (USD вместо KZT) специалиста из Алма-аты (Евразийский банк, АО) привела к искажению всех графиков. Сумма 380 000 USD равна 24 304 876 руб. Поэтому ниже построены графики для заработной платы ниже 500 000 руб. Из которых видно, что в основном, желаемый уровень заработной платы составляет от 40 000 до 100 000 рублей.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
mask = hh_data['ЗП (руб)'] < 1_000_000
data_bar = hh_data[mask].copy()
data_bar = data_bar.groupby(by=['Образование'],as_index=False)['ЗП (руб)'].median()

fig = px.bar(
    data_frame = data_bar,
    x = 'Образование',
    y = 'ЗП (руб)',
    color = 'Образование',
    color_discrete_sequence=["grey", "green", "goldenrod", "blue"],
    labels={'ЗП (руб)':'Заработная плата, руб'},
    title= 'Зависимость заработной платы соискателей на HeadHunter от образования'
)
fig.show()

fig.write_html("plotly/bar_salary_education.html")

# %% [markdown]
# Из графиков следует, что признак 'Образование' важен для прогнозирования заработной платы. Желаемая заработная плата у людей с высшим образованием, выше, чем у других соискателей.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
mask = hh_data['ЗП (руб)'] < 1_000_000
data_box = hh_data[mask]. copy()

fig = px.box(
    data_frame = data_box,
    x = 'Город',
    y = 'ЗП (руб)',
    color = 'Город',
    color_discrete_sequence=["orange", "green", "blue"],
    labels={'ЗП (руб)':'Заработная плата, руб'},
    title= 'Зависимость заработной платы соискателей на HeadHunter от города',
    width=1200, 
    height=800
)
fig.show()

fig.write_html("plotly/box_salary_city.html")

# %% [markdown]
# Для категорий "другие" и "город-миллионник" медианое значение около 40 000 и межквартильное расстояние равно 30 000. В Москве медиана около 85 000 и межквартильное расстояние равно 90 000. В Санкт-Петербургет медиана около 60 000 и межквартильное расстояние около 40 000. Наибольший межквартильный размах по отношения к медианному значению в Москве. Возможно, это говорит о бОльшем социальном расслоении в Москве, но возможно это связано, с тем, что бОльшее количество разных людей ищут разные вакансии, то есть связано с тем, что люди разные, но все они имеют бОльшую предрасположенность к смене работы.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
data_bar = hh_data.copy()

data_bar['Готовность к переезду'] = data_bar['Готовность к переезду'].apply(lambda x : "Готов к переезду" if x else 'Не готов к перезду')
data_bar['Готовность к командировкам'] = data_bar['Готовность к командировкам'].apply(lambda x : "Готов" if x else 'Не готов')

data_bar = data_bar.groupby(by=['Готовность к переезду','Готовность к командировкам'],as_index=False)['ЗП (руб)'].median()

fig = px.bar(
            data_frame = data_bar, 
            x="Готовность к переезду", 
            y="ЗП (руб)", 
            color="Готовность к командировкам", 
            barmode="group",
            color_discrete_sequence=["green", "orange"],
            labels={'ЗП (руб)':'Заработная плата, руб'},
            title= 'Зависимость заработной платы соискателей на HeadHunter от готовности к переезду и готовности к командировкам',
            width=1200, 
            height=800
            )    
fig.show()

fig.write_html("plotly/bar_salary_move.html")

# %% [markdown]
# Из графиков следует, что готовность соискателя к командировкам и/или перезду выражается в росте его желаемой заработной платы.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# Функция разделяющая возраст по группам. 
def get_age_cat(age):
    if age < 20:
        return "До 20"
    elif age >= 20 and age < 25:
        return "От 20 до 24"
    elif age >= 25 and age < 30:
        return "От 25 до 29"
    elif age >= 30 and age < 35:
        return "От 30 до 34"
    elif age >= 35 and age < 40:
        return "От 35 до 39"
    elif age >= 40 and age < 45:
        return "От 40 до 44"
    elif age >= 45 and age < 50:
        return "От 45 до 49"
    elif age >= 50 and age < 55:
        return "От 50 до 54"
    elif age >= 55 and age < 60:
        return "От 55 до 59"
    elif age >= 60 and age < 65:
        return "От 60 до 64"
    elif age >= 65:
        return "от 65 и старше"

# %%
fig = plt.figure(figsize=(12,6))
axes = fig.add_axes([0,0,1,1])

heatmap_data = hh_data.copy()
heatmap_data['Категория возраста'] = heatmap_data['Возраст'].apply(get_age_cat)
heatmap_data = heatmap_data.pivot_table(values='ЗП (руб)',index=['Категория возраста'],columns=['Образование'],aggfunc=['median'])

colormap = sns.color_palette("coolwarm", 12)

hm = sns.heatmap(
    heatmap_data,
    linewidth=1,
    linecolor='b',
    cmap=colormap,
    annot=True,
    fmt='.0f' 
)

hm.invert_yaxis()
hm.invert_xaxis()
hm.set_ylabel('Категории возраста, лет')
hm.set_xlabel('Уровень образования')
hm.set_xticklabels(['высшее','неоконченное высшее','среднее','среднее специальное'])
hm.set_title('Зависимость желаемой заработной платы соискателей HH'+'\n'+'от категориям возраста и от уровня образования');

# %% [markdown]
# После 20 лет, по мере затраченного времени на получение высшего образования, желаемая заработная плата соискателей с высшим образованием растёт. Около 40 лет желаемая заработная плата соискателей с вышим образованием в два раза больше желаемой заработной платы людей со средним образованием. Возможно, многие работодатели готовы взять на более высокооплачиваемые должности людей с высшим образованием.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
fig = plt.figure(figsize=(12,4))
axes = fig.add_axes([0,0,1,1])

sp_data = hh_data.copy()
sp_data['Опыт работы (год)'] = sp_data['Опыт работы (месяц)'] / 12

scatterplot = sns.scatterplot(
    data=sp_data,
    x='Возраст',
    y='Опыт работы (год)',
    ax=axes    
)

scatterplot.set_xlim(0,110)
scatterplot.set_ylim(0,110)
scatterplot.set_xticks( np.arange(0, 110, 10) )
scatterplot.set_yticks( np.arange(0, 110, 10) )
scatterplot.set_xlabel('Возраст, год')
scatterplot.set_ylabel('Опыт работы, год')
scatterplot.set_title('Зависимость опыта работы соискателей HH от их возраста')

plt.plot([0,100], [0,100], "r--")
plt.show();

# Для просмотра данных, вызывающих вопросы можно снять знаки комментариев ниже
# mask = sp_data['Опыт работы (год)'] > sp_data['Возраст']
#display(sp_data[mask])

# %% [markdown]
# У семи соискателей опыт работы превышает их возраст. Для таких соискателей, по крайней мере признак 'Опыт работы' заполнен не верно. Возможно, все данные таких соискателей надо исключить из модели, так как заполнение данных этими соискателями скомпроментированно.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# Построение зависимости медианной заработной платы от месяца создания резюме, 
# это может показать есть ли какой-то тренд, который в свою очередь может быть связан
# с экономическими факторами (например, инфляция)  

# словарь для перевода названия месяцев на русский язык

ru_months = { 1: 'Январь', 2: 'Февраль', 3: 'Март', 4: 
    'Апрель', 5: 'Май', 6: 'Июнь', 
    7: 'Июль', 8: 'Август', 9: 'Сентябрь', 
    10: 'Октябрь', 11: 'Ноябрь', 12: 'Декабрь'}

# Чуть офильтровал данные
mask  = (hh_data['ЗП (руб)'] >5_000) & (hh_data['ЗП (руб)']< 1_000_000)

plot_data = hh_data[mask].copy()

# Создание нового признака с отдельно выделенной датой (потребуется для сортировки)
plot_data['Дата обновления резюме'] = \
    pd.to_datetime(
                plot_data ['Обновление резюме'],format='%d.%m.%Y %H:%M'
                ).dt.date.astype('datetime64[ns]')

# Создание нового признака с отдельно выделенным номером месяцем
plot_data['Номер месяца обновления резюме'] = \
    pd.to_datetime(
                plot_data ['Обновление резюме'],format='%d.%m.%Y %H:%M'
                ).dt.month

# Создание нового признака с русским месяцем
plot_data['Месяц обновления резюме'] = plot_data['Номер месяца обновления резюме'].apply(lambda x : ru_months[x][:3] )
    
plot_data['Год обновления резюме'] = \
    pd.to_datetime(
                plot_data ['Обновление резюме'],format='%d.%m.%Y %H:%M'
                ).dt.year
    
# Создание нового признака с номером года и русским месяцем  
plot_data['Год и Месяц обновления резюме'] = plot_data['Год обновления резюме'].astype(str) + ' ' + plot_data['Месяц обновления резюме'].astype(str)

# сортировка по датам и группировка без изменения сортировки с медианой заработной платы
plot_data_1 = plot_data.sort_values(['Дата обновления резюме']).\
    groupby(by=['Год и Месяц обновления резюме'],sort=False,as_index=False)['ЗП (руб)'].median()



# Создание графика с зависимостью количества резюме от месяца/года
# Проверка динамики количество резюме (примерно постоянная величина или нет)

fig = plt.figure(figsize=(12,12))
axes = fig.subplots(2, 1)

lineplot = sns.lineplot(
    data=plot_data_1,
    x = 'Год и Месяц обновления резюме',
    y = 'ЗП (руб)',
    
    ax=axes[0]
    )
lineplot.set_title('Динамика зависимости заработной платы от месяца обновления резюме', fontsize=16)
lineplot.set_xlabel('Месяц создания резюме')
lineplot.set_ylabel('Уровень заработной платы, руб')
max_x_ticks = plot_data_1['Год и Месяц обновления резюме'].count()
lineplot.set_xticks( np.arange(0, max_x_ticks, 2) );

# сортировка по датам и группировка без изменения сортировки с количеством дат создания (кол-во резюме в период)
plot_data_2 = plot_data.sort_values(['Дата обновления резюме']).\
    groupby(by=['Год и Месяц обновления резюме'],sort=False,as_index=False)['Дата обновления резюме'].count()

lineplot = sns.lineplot(
    data=plot_data_2,
    x = 'Год и Месяц обновления резюме',
    y = 'Дата обновления резюме',
    ax=axes[1]
    )
lineplot.set_title('Динамика зависимости количества резюме от месяца обновления резюме', fontsize=16)
lineplot.set_xlabel('Месяц создания резюме')
lineplot.set_ylabel('Количество резюме (логарифмическая шкала)')
max_x_ticks = plot_data_2['Год и Месяц обновления резюме'].count()
lineplot.set_xticks( np.arange(0, max_x_ticks, 2) )
plt.yscale('log');


# Для просмотра данных, вызывающих вопросы можно снять знаки комментариев ниже ВНИМАНИЕ изменение DataFrame 
#hh_data['Обновление резюме'] = pd.to_datetime(
#                hh_data ['Обновление резюме'],format='%d.%m.%Y %H:%M'
#                ).dt.date.astype('datetime64[ns]')
#
#mask = hh_data['Обновление резюме'] < pd.to_datetime('01.01.2019',format='%d.%m.%Y'
#                )

#display(hh_data[mask].info())

# %% [markdown]
# На верхнем графике есть значительное снижение уровня заработной платы с конца 1 квартала 2019. На втором графике есть резкий рост количества обновлений резюме в аналогичный период. Причем видно, что графики сверху и снизу разнонаправленны. Можно, конечно, предположить влияние экономических изменений: все люди (из разных слоёв) начали активно в 1 квартале 2019 года искать работу, снизив планку заработной платы. Но, возможно, эти данные просто обусловлены составлением базы данных компанией Skillfactory.

# %%
# Проверка зависимости уровня заработной платы от Пола соискателя
# При этом надо посмотреть распределение Пола соискателя в целом

fig = plt.figure(figsize=(16,8))
axes = fig.subplots(1, 2)

# Чуть офильтровал данные
mask  = (hh_data['ЗП (руб)'] >5_000) & (hh_data['ЗП (руб)']< 1_000_000)

pie_data = hh_data[mask].groupby(by=['Пол'],as_index=False)['ЗП (руб)'].mean()

axes[0].pie(
    pie_data['ЗП (руб)'],
    labels=pie_data['Пол'],
    autopct='%.2f%%',
    explode = [0.2, 0],
    colors=['Orange','Green'],
    rotatelabels =True, 
    startangle=120,
    counterclock=False    
);
axes[0].set_title('Ожидаемые заработные платы женщин и мужчин \n среди соискателей HH', fontsize=12)


pie_data = hh_data.groupby(by=['Пол'],as_index=False)['ЗП (руб)'].count()

axes[1].pie(
    pie_data['ЗП (руб)'],
    labels=pie_data['Пол'],
    autopct='%.2f%%',
    explode = [0.2, 0],
    colors=['Orange','Green'],
    rotatelabels =True, 
    startangle=70,
    counterclock=False    
);
axes[1].set_title('Доли женщин и мужчин \n среди соискателей HH', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Доли женщин и мужчин \n среди соискателей HH')

# %% [markdown]
# Из графиков следует, что ожидаемые заработные платы у мужчин пока ещё ) выше, чем у женщин. Значит есть влияние гендерного признака на ожидаемую заработную плату.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
dupl_columns = list(hh_data.columns)
mask = hh_data.duplicated(subset=dupl_columns)
hh_duplicates = hh_data[mask]
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}')
hh_data = hh_data.drop_duplicates(subset=dupl_columns)
# Out:
# Число найденных дубликатов: 158

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
display(sum(hh_data['Опыт работы (месяц)'].isnull()))
# Out:
# 168

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh_data = hh_data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы (месяц)'].fillna(hh_data['Опыт работы (месяц)'].median())

# %%
display(hh_data['Опыт работы (месяц)'].mean())
# Out:
# 114.35831239906693

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
mask = (hh_data['ЗП (руб)'] < 1_000) | (hh_data['ЗП (руб)'] > 1_000_000)
display(hh_data[mask].shape[0])
hh_data.drop(hh_data[mask].index,inplace=True)
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
mask = (hh_data['Опыт работы (месяц)'] / 12) > hh_data['Возраст']
display(hh_data[mask].shape[0])
hh_data.drop(hh_data[mask].index,inplace=True)
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

log_age = np.log(hh_data['Возраст']).astype(float)
histplot = sns.histplot(
                        log_age, 
                        bins=30, 
                        ax=axes
                        )

histplot.axvline(log_age.mean(), color='r', lw=2)
histplot.axvline(log_age.mean()+ 4 * log_age.std(), color='g', ls='--', lw=2)
histplot.axvline(log_age.mean()+ 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)

histplot.set(xlabel="Возраст (логарифм)", ylabel = "Количество")
histplot.set_title('Распределение возраста соискателей HH');

# %%
# Решил написать небольшую функцию для определения характера ассиметрии
# первый аргумент - это показатель ассиметрии, второй аргумент - это требуемая точность (по умолчанию 0)

fun_skew =  lambda x,e=0 : 'правая ассимметрия 'if x > e else ('левая ассиметрия' if x < -e else 'асимметрии нет')
data_skew = fun_skew(log_age.skew())

print(f'Признак ассиметрии данных - {data_skew}')
# Out:
# Признак ассиметрии данных - правая ассимметрия

# %% [markdown]
# График логарифма возраста построенный по методу 3-х сигм ($\sigma$) имеет правостороннюю ассимметрию. Линия среднего значения (красная) находится правее моды. На графике показано увеличение правой границы на одну сигму (вертикальная зелёная пунктирная линия)

# %%
# Функция Skillfactory
def outliers_z_score(data, feature, log_scale=False,left=3,right=3):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

# "Послабление" вправо на 1 сигму
outliers, cleaned = outliers_z_score(hh_data, 'Возраст', True,3,4)
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
# Out:
# Число выбросов по методу z-отклонения: 3
# Результирующее число записей: 44485
